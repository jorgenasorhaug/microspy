# %% [markdown]
# # Import libraries

# %%
# %matplotlib qt

import numpy as np
import matplotlib.pyplot as plt

import microspy as ms

# %% [markdown]
# # Load signal

# %%
s = ms.load("inspected.hdf5")

# %%
s

# %%
s.Images

# %% [markdown]
# ## Classifying particles
# Sometimes, the vendor have built-in classification schemes in their software. Either you acn specify them yourself, or there are classification schemes that takes into account a standard. If any classification scheme is performed, the data will be read using microspy.
#
# Let's check what kind of classes the different particles have been classified with:

# %%
s.particle_classes
